# %% [markdown]
# <a href="https://colab.research.google.com/github/Sameeulla-A/PyTorch/blob/main/Python/3_lists_Part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lst = [1,2,3,5,6,8]
print(lst)
lst.append(9)
print(lst)
# Out:
# [1, 2, 3, 5, 6, 8]
# [1, 2, 3, 5, 6, 8, 9]

# %% [markdown]
# * In DL we're going to print out some info about the model and then we test the model or we modify the model and then we print out that same information and we see what changed from this line of code.
# * Insert is another method we use in python with list.
# * append will add the value at the end of the list where as insert will use index number to position the value wherever we want.
# * python starts counting from 0 left side and -1 from the right side, which also called as indexing.

# %%
print(lst)
lst.insert(2,9)
print(lst)
# Out:
# [1, 2, 3, 5, 6, 8, 9]
# [1, 2, 9, 3, 5, 6, 8, 9]

# %% [markdown]
# what happens if we insert string?

# %%
print(lst)
lst.insert(2,"hello")
print(lst)
# Out:
# [1, 2, 9, 3, 5, 6, 8, 9]
# [1, 2, 'hello', 9, 3, 5, 6, 8, 9]

# %% [markdown]
# python is completely okay to insert the strings to the list, means lists can contain different types of variables.

# %% [markdown]
# Help in Python.
#
# Place the cursor inside the function (|) and press and Hold shift
#
# ![image.png](data:image/png;base64,...)
#
# then a window will get openup and give us some little information.

# %%
lst.remove(9)
lst
# Out:
# [1, 2, 'hello', 3, 5, 6, 8, 9]

# %% [markdown]
# removed first occurance of 9 in the list.
# let's try another one.

# %%
lst.remove(19)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_483/2325732532.py in <cell line: 0>()
# ----> 1 lst.remove(19)
#
# ValueError: list.remove(x): x not in list

# %% [markdown]
# 19 is not in the list.

# %%
lst.sort()
lst
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_483/1496198826.py in <cell line: 0>()
# ----> 1 lst.sort()
#       2 lst
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %% [markdown]
# sorting supports only int but not string.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Exercise !!
#
# remove the string and sort the list with remaining numbers.

# %%
lst.remove('hello')
lst.sort()
print(lst)
lst.sort(reverse=True)
lst
# Out:
# [1, 2, 3, 5, 6, 8, 9]
# [9, 8, 6, 5, 3, 2, 1]
