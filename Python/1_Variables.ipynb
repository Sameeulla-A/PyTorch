# %% [markdown]
# <a href="https://colab.research.google.com/github/Sameeulla-A/PyTorch/blob/main/Python/1_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# to execute the code in the cell we use ctrl + enter

# %%
7  # input and the below is the output.
# Out:
# 7

# %%
# new cell short cuts
# +Code below every cell
# + Code above the first cell
# Alt + Enter for new cell'''

# %%
a = 4

# %%
a + 9
# Out:
# 13

# %%
b = 5

# %%
a
# Out:
# 4

# %%
b
# Out:
# 5

# %%
a
b
# Out:
# 5

# %% [markdown]
# in the above python remembers only the last line of code.

# %%
print(a)
print(b)
# Out:
# 4
# 5

# %% [markdown]
# Comments: a piece of text that you write as information or identification of the code

# %%
# we do comment with pound(#) value, then the text will be turned green. everything after the sign will be ignored in python. we can have after the code, between the codes,

# %%
c = 7
d = 7.0
# for a human eye both are same but for computer c is an integer and the d is a float data type.

# %%
# print type of c variable
print(type(c))
type(d)
# Out:
# <class 'int'>
# float

# %%
e = 'hello'
f = "world"
print(type(e))
print(type(f))
# Out:
# <class 'str'>
# <class 'str'>

# %% [markdown]
# we can have single qutes inside the double quotes, but not double inside the single.

# %% [markdown]
# single letter variables are not good in coding.

# %%
# naming convention:
aVariaBleName = 10
FilterOrder = 18
Iser_name = 'sami'
param4modelA = 43.58755

Not allowed variable = 34
not!allowed = 323
# ! is a reserved, except _ we cannot user other letters. ( ) is not allowed
2variable =2 #variable cannot start with number.
# Out:
#   File "/tmp/ipykernel_566/1061439720.py", line 10
#     2variable =2 #variable cannot start with number.
#     ^
# SyntaxError: invalid decimal literal

# %%
 characterstics of variables, properties of variables we can found with %magic key word called hwos.
# Out:
#   File "/tmp/ipykernel_566/126327157.py", line 1
#     characterstics of variables, properties of variables we can found with %magic key word called hwos.
#                    ^
# SyntaxError: invalid syntax

# %%
# %whos
# Out:
# Variable   Type     Data/Info
# -----------------------------
# a          int      4
# b          int      5
# c          int      7
# d          float    7.0
# e          str      hello
# f          str      world

# %% [markdown]
# as the above variables get larger, they contain more and more complex, then we are not going get the actual data. we get some meta information about the variables.

# %%
# multiple assigments
varA = 3
varB = 'test'
print(varA)
print(varB)
# Out:
# 3
# test

# %%
varC, varD = 5, 'road'
print(varC)
print(varD)
# Out:
# 5
# road

# %% [markdown]
# can be used in multiple assignements variables, where variable are relatively short name. and relatively small values to assign to them.

# %%
# Excercise!
#   - Can you overwrite existing variables?
#   - using the same variable type
#   - using different variable type

# %%
varE = 5
varF = 'variable'
print(type(varE))
print(type(varF))
varE = 'variable'
varF = 5
print(type(varE))
print(type(varF))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>

# %%
# answer to the excercise, yes we can overwrite the varibales, iresspective of variable type.
