# %% [markdown]
# <a href="https://colab.research.google.com/github/Sameeulla-A/PyTorch/blob/main/2_Math_and_Printing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 7
y = 4.3
z = 0

# %%
y + x -7
# Out:
# 4.300000000000001

# %% [markdown]
# if we use to do the above calc we will get 4.3. but here we are getting 4.300000000000001 some values extra. shorter version of the explation is floating point algebra is not same thing as real algebra. here we are not actully implementing real algebra, it's called floating point algebra. because computers have limited precision, they cannot represent arbitratily small or arbitrarlily large numbers. so we get some tiny, tiny computer rounding errors they are essentially zeros.

# %%
c = y + 3.5*x - 7
c
# Out:
# 21.8

# %%
4/3
# Out:
# 1.3333333333333333

# %%
4\
  3
# \ indicating to python to continue the line of code into the next line of text.
# Out:
#   File "/tmp/ipykernel_2292/2376776811.py", line 2
#     3
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# this is two lines of text, but it's one line of code, \ treated as space in python

# %%
4 \
  + 3 # it would be a meaning ful
# Out:
# 7

# %%
3*2 # multiplication
# Out:
# 6

# %%
 9**2  #root
# Out:
# 81

# %%
9**1/2
# Out:
# 4.5

# %% [markdown]
# it should be equal to 3, but python follows the order of operations. python interpreting (9**1)/2. let's reorder the same.

# %%
9**(1/2) # 9 power of the half
# Out:
# 3.0

# %%
Firstname = 'mike'
lastname = 'cohen'

Firstname + lastname
# Out:
# 'mikecohen'

# %% [markdown]
# + sign can be used concatenation on strings, this is a phenomenon in codeing called overloading.
# overloading is a term when you have the same operation that's used in different ways depending on the context. so this plus sign means to do mathematical addition with number and concatenation with strings.

# %%
fullname = Firstname + ' ' + lastname  # ' ' used for space
fullname
# Out:
# 'mike cohen'

# %%
# let's do a substraction
Firstname - lastname
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3047/757873045.py in <cell line: 0>()
#       1 # let's do a substraction
# ----> 2 Firstname - lastname
#
# NameError: name 'Firstname' is not defined

# %% [markdown]
# python know what to with + and it doesn't know what to do with - while working with Strings

# %%
Firstname*3   # prints 3 times
# Out:
# 'mikemikemike'

# %%
print('7*3 = 21')
print('7*3 = 2.1')
# Out:
# 7*3 = 21
# 7*3 = 2.1

# %% [markdown]
# in the above we are not doing math, it's a string thing and we are printing the strings not numbers.

# %%
print(x+y)  # here variables used without quotes.
print('x+y') #here variables used within the quotes, so python treated as string.
# Out:
# 11.3
# x+y

# %%
print(x + ' + ' + y + ' = ' + x+y) # here we are trying to combine strings and Ints
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3047/2503343367.py in <cell line: 0>()
# ----> 1 print(x + ' + ' + y + ' = ' + x+y) # here we are trying to combine strings and Ints
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print(str(x) + ' + ' + str(y) + ' = ' + str(x+y))
# Out:
# 7 + 4.3 = 11.3

# %% [markdown]
# in the above we used str() funtion to convert the int / float into string. it's a complecated code, visually.

# %%
print(f' x + ' + ' + y + ' == ' + x+y')
# Out:
# False

# %% [markdown]
# input() function allows user to input the data.

# %%
ans = input('Give Me a Number: ')
# Out:
# Give Me a Number: 8

# %%
ans # gives the output in ''s means it's a string.
# Out:
# '8'

# %%
type(ans)
# Out:
# str

# %%
ans + 8 #string + int doesn't support.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3047/4011075414.py in <cell line: 0>()
# ----> 1 ans + 8
#
# TypeError: can only concatenate str (not "int") to str

# %%
int(ans) + 8   #converted into integer
# Out:
# 16

# %%
float(ans) + 7 # converted into float
# Out:
# 15.0

# %%
qns = float( input('Give me a number: '))
type(qns)
# Out:
# Give me a number: 15.2
# float

# %%
# Exercise!
# Lets test the Pythagorean Theorem.
# c^2 = a^2 + b^2
# c**2 = a**2 + b**2

# get two input from the user
#   side 'a'
#   side 'b'
# - compute and print out the length of side c!

# %%
a = float(input('side a: '))
b = float(input('side b: '))
c = a**2 + b**2
print(f'side c: {c}')
# Out:
# side a: 15.2
# side b: 15.2
# side c: 462.08

# %% [markdown]
# code worked but, not exactly as theorem

# %%
a = float(input('side a: '))
b = float(input('side b: '))
c = (a**2 + b**2)**(1/2)
print('side c is ' + str(c))
# Out:
# side a: 15.2
# side b: 15.2
# side c is 21.496046148071045
